# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os

# %%
from mnist import MNIST
from mlpalae import MlpAlae
from trainer import Trainer

# %%
tf.random.set_seed(1234)
np.random.seed(1234)
tf.keras.backend.set_floatx('float64')

mnist = MNIST()
mlpalae = MlpAlae()

trainer = Trainer('./summary/', './ckpt/')
trainer.train(mlpalae, 50, mnist.cdatasets(), mnist.cdatasets(train=False))
# Out:
#   0%|                                                                                                           | 0/50 [00:00<?, ?it/s]
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float32 to the layer's dtype of float64, which is new behavior in TensorFlow 2.  The layer has dtype float64 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float64, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float32 by default, call `tf.keras.backend.set_floatx('float32')`. To change just this layer, pass dtype='float32' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [18:28<00:00, 22.17s/it]

# %%
x_train, y_train = mnist.rawdata()
x_test, y_test = mnist.rawdata(train=False)

# trainset = np.concatenate((x_train.reshape(-1, 784), np.eye(10)[y_train]), axis=-1)
# testset = np.concatenate((x_test.reshape(-1, 784), np.eye(10)[y_test]), axis=-1)
trainset = np.concatenate((x_train.reshape(-1, 784), np.zeros((x_train.shape[0], 10))), axis=-1)

# %%
idx = 1
latent, image = mlpalae(trainset[idx:idx + 1].reshape(1, 784 + 10))
plt.imshow(np.clip(image.numpy()[0, :784].reshape(28, 28), 0, 1), cmap='gray')

# %%
idxA, idxB = 27, 62
latentA = mlpalae.encoder(trainset[idxA:idxA + 1].reshape(1, 784 + 10))
latentB = mlpalae.encoder(trainset[idxB:idxB + 1].reshape(1, 784 + 10))

# %%
num = 5
delta = (latentB - latentA) / num
fig, axs = plt.subplots(1, num + 1)

latent = latentA
for i in range(num + 1):
    image = mlpalae.generator(latent).numpy()[0, :784].reshape(28, 28)
    plt.setp(axs[i].get_xticklabels(), visible=False)
    plt.setp(axs[i].get_yticklabels(), visible=False)
    axs[i].imshow(np.clip(image, 0, 1), cmap='gray')
    latent += delta

plt.savefig('polymorph', bbox_inches='tight', pad_inches=0)

# %%
cherrypicked = [37, 14, 76, 27, 20, 138, 62, 15, 41, 4 ]
fig = plt.figure(figsize=(5, 2))
axs = [fig.add_subplot(2, 5, i + 1) for i in range(10)]

for i in range(10):
    ax = axs[i]
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_aspect('equal')
    
    idx = cherrypicked[i]
    latent, image = mlpalae(trainset[idx:idx + 1].reshape(1, 784 + 10))
    ax.imshow(np.clip(image[0, :784].numpy().reshape(28, 28), 0, 1), cmap='gray')

plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig('enum', bbox_inches='tight', pad_inches=0)
